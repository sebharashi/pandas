# %%
import pandas as pd

# %%
pf=pd.read_csv('pandas_docs/survey_results_public.csv')
pf
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# ### - retrieve first 5 rows with all columns age

# %%
pf.iloc[5,:]
# Out:
# Respondent                                                      6
# MainBranch      I am not primarily a developer, but I write co...
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                              East Asian
# Dependents                                                     No
# SurveyLength                                             Too long
# SurveyEase                             Neither easy nor difficult
# Name: 5, Length: 85, dtype: object

# %%
pf.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ### - Retrieve repondents 450,900,1350 with only their country,Hobbyist,YearsCode,Age1stCode

# %%
pf.iloc[[450,900,1350],[pf.columns.get_loc('Country'),pf.columns.get_loc('Hobbyist'),pf.columns.get_loc('YearsCode'),pf.columns.get_loc('Age'),pf.columns.get_loc('Age1stCode')]]
# Out:
#             Country Hobbyist YearsCode   Age Age1stCode
# 450   United States      Yes         7  35.0         28
# 900            Iran      Yes         6  22.0         16
# 1350         Mexico      Yes        10  36.0          9

# %% [markdown]
# ### - retrieve respondent 500 and his age

# %%
pf.iloc[500,pf.columns.get_loc('Age')]
# Out:
# 21.0

# %% [markdown]
# ### - 1000t row > Country

# %%
pf.loc[1000,'Country']
# Out:
# 'United Kingdom'

# %% [markdown]
# ### - 30th row > Hobbyist

# %%
pf.loc[30,'Hobbyist']
# Out:
# 'No'

# %% [markdown]
# ### - 300th row >devtype

# %%
pf.loc[300,'DevType']
# Out:
# 'Developer, back-end;Developer, desktop or enterprise applications;Developer, game or graphics'

# %% [markdown]
# ### - access 50-150

# %%
pf.loc[50:150]
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 50           51             I am a student who is learning to code      Yes
# 51           52                     I am a developer by profession      Yes
# 52           53  I am not primarily a developer, but I write co...      Yes
# 53           54                     I am a developer by profession      Yes
# 54           55             I am a student who is learning to code      Yes
# ..          ...                                                ...      ...
# 146         148                     I am a developer by profession      Yes
# 147         149                     I am a developer by profession      Yes
# 148         150                     I am a developer by profession      Yes
# 149         151                     I am a developer by profession      Yes
# 150         152                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# ### - without start

# %%
pf.loc[:150]
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 0             1             I am a student who is learning to code      Yes
# 1             2             I am a student who is learning to code       No
# 2             3  I am not primarily a developer, but I write co...      Yes
# 3             4                     I am a developer by profession       No
# 4             5                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 146         148                     I am a developer by profession      Yes
# 147         149                     I am a developer by profession      Yes
# 148         150                     I am a developer by profession      Yes
# 149         151                     I am a developer by profession      Yes
# 150         152                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# ### - without end

# %%
pf.loc[150:]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 150           152                     I am a developer by profession      Yes
# 151           153                     I am a developer by profession      Yes
# 152           154                     I am a developer by profession       No
# 153           155                     I am a developer by profession      Yes
# 154           156  I am not primarily a developer, but I write co...       No
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# ### - Retrieve 1000th respondent with his salary and Country he belongs from

# %%
pf.loc[1000,['ConvertedComp','Country']]
# Out:
# ConvertedComp          130847.0
# Country          United Kingdom
# Name: 1000, dtype: object

# %% [markdown]
# ### - Retrieve top 45 rows form first 5 columns and return their data type(do this on top 2 different data sets)

# %%
f=pf.iloc[:45,:5]
f
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
f.dtypes
# Out:
# Respondent      int64
# MainBranch     object
# Hobbyist       object
# OpenSourcer    object
# OpenSource     object
# dtype: object

# %% [markdown]
# ### - Retrieve Multiple columns with multiple rows from two dataframes

# %%
pf.iloc[[0,5,7],[55,60,65]]
# Out:
#                                           Containers OffOn  \
# 0                            I do not use containers   Yes
# 5                            I do not use containers    No
# 7  Development;Testing;Production;Outside of work...   Yes
#
#                        SOVisitFreq
# 0  A few times per month or weekly
# 5  A few times per month or weekly
# 7             A few times per week

# %%
pd.read_csv('chessmasters.csv')
# Out:
#   Unnamed: 0 Unnamed: 1     test     test   test.1   test.2  test.3
# 0     Magnus     Magnus   Magnus   Magnus   Magnus   Magnus     NaN
# 1    Carlsen    Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
pf.iloc[[0,1],[4,5]]
# Out:
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work

# %% [markdown]
#  ### - Retrieve last 5 rows and last 5 columns and return their column names only

# %%
v=pf.iloc[-5:,-5:]
v
# Out:
#                      Sexuality  \
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength SurveyEase
# 88878  Appropriate in length       Easy
# 88879                    NaN        NaN
# 88880                    NaN        NaN
# 88881                    NaN        NaN
# 88882  Appropriate in length       Easy

# %%
v.columns
# Out:
# Index(['Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'], dtype='object')

# %% [markdown]
# ### - get the index postition any column

# %%
pf.columns.get_loc('Age')
# Out:
# 77

# %% [markdown]
# ### - Create a dictionary which contains keys> Name, Marks,Result
# ### - convert dictionary into dataframe
# ### - Access values using square barackets
# ### - access values using iloc
#  ### -access values using loc

# %%
dic={'name':['rajeer','adnan','nemi','yasir'], 'marks':[42,57,74,50], 'results':['fail','pass','pass','fail']}
dic
# Out:
# {'name': ['rajeer', 'adnan', 'nemi', 'yasir'],
#  'marks': [42, 57, 74, 50],
#  'results': ['fail', 'pass', 'pass', 'fail']}

# %%
q=pd.DataFrame(dic)
q
# Out:
#      name  marks results
# 0  rajeer     42    fail
# 1   adnan     57    pass
# 2    nemi     74    pass
# 3   yasir     50    fail

# %%
q.iloc[2]
# Out:
# name       nemi
# marks        74
# results    pass
# Name: 2, dtype: object

# %%
q.loc[3,'results']
# Out:
# 'fail'

# %% [markdown]
# ### - Create a data frame which inlcudes a columns with serial number and id columns

# %%
dic={'S.no':[1,2,3,4],'id':['a','b','c','d'],'name':['rajeer','adnan','nemi','yasir'], 'marks':[42,57,74,50], 'results':['fail','pass','pass','fail']}
p=pd.DataFrame(dic)
p
# Out:
#    S.no id    name  marks results
# 0     1  a  rajeer     42    fail
# 1     2  b   adnan     57    pass
# 2     3  c    nemi     74    pass
# 3     4  d   yasir     50    fail

# %% [markdown]
# ### - make serial column as an index and access any value

# %%
p.set_index('S.no',inplace=True)

# %%
p.loc[3]
# Out:
# id            c
# name       nemi
# marks        74
# results    pass
# Name: 3, dtype: object

# %% [markdown]
# ### - make id column into index and access value

# %%
p.set_index('id',inplace=True)

# %%
p.loc['c']
# Out:
# name       nemi
# marks        74
# results    pass
# Name: c, dtype: object

# %% [markdown]
# # - On survery Data

# %% [markdown]
#  ### - How old all the fist 30 respondents

# %%
pf.loc[:30,'Age']
# Out:
# 0     14.0
# 1     19.0
# 2     28.0
# 3     22.0
# 4     30.0
# 5     28.0
# 6     42.0
# 7     24.0
# 8     23.0
# 9      NaN
# 10    22.0
# 11    21.0
# 12    28.0
# 13    31.0
# 14    20.0
# 15    26.0
# 16    29.0
# 17     NaN
# 18    31.0
# 19    38.0
# 20     NaN
# 21    47.0
# 22    22.0
# 23    23.0
# 24    22.0
# 25    34.0
# 26    22.0
# 27     NaN
# 28    32.0
# 29    28.0
# 30     NaN
# Name: Age, dtype: float64

# %% [markdown]
#  ### - Preferred gender of 50 to 100 respondents

# %%
pf.loc[50:100,'Gender']
# Out:
# 50                                                 Woman
# 51                                                   Man
# 52                                                   Man
# 53                                                   Man
# 54                                                   Man
# 55                                                   Man
# 56                                                   Man
# 57                                                   Man
# 58                                                   Man
# 59                                                   Man
# 60                                                   Man
# 61                                                   Man
# 62                                                   Man
# 63                                                   Man
# 64                                                   Man
# 65                                                   NaN
# ...

# %% [markdown]
# ### - Most number of repondents are from which country

# %%
pf['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
pf.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ### - EdLevel and YearsCodPro of 1000 to 1050

# %%
pf.loc[1000:1050,['EdLevel','YearsCodePro']]
# Out:
#                                                 EdLevel      YearsCodePro
# 1000           Bachelor’s degree (BA, BS, B.Eng., etc.)                10
# 1001        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 2
# 1002           Bachelor’s degree (BA, BS, B.Eng., etc.)                 3
# 1003  Some college/university study without earning ...                 5
# 1004  Some college/university study without earning ...                20
# 1005           Bachelor’s degree (BA, BS, B.Eng., etc.)                 4
# 1006        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 6
# 1007        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 2
# 1008  Some college/university study without earning ...                 2
# 1009           Bachelor’s degree (BA, BS, B.Eng., etc.)  Less than 1 year
# 1010        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 7
# 1011        Master’s degree (MA, MS, M.Eng., MBA, etc.)                12
# ...

# %% [markdown]
#  ### - How many respondents are students

# %%
pf['Student'].value_counts()
# Out:
# Student
# No                65816
# Yes, full-time    15769
# Yes, part-time     5429
# Name: count, dtype: int64

# %% [markdown]
#  ### - Response of first 20 respondents to "Student" to "YearsCodePro"

# %%
pf.loc[:20,'Student':'YearsCodePro']
# Out:
#            Student                                            EdLevel  \
# 0               No                          Primary/elementary school
# 1   Yes, full-time  Secondary school (e.g. American high school, G...
# 2               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7              NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8               No  Some college/university study without earning ...
# 9               No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 10  Yes, full-time                          Primary/elementary school
# 11  Yes, full-time  Some college/university study without earning ...
# ...

# %% [markdown]
#  ### - Return the columns names of all the object type columns

# %%
pf.select_dtypes('object')
# Out:
#                                               MainBranch Hobbyist  \
# 0                 I am a student who is learning to code      Yes
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# ...                                                  ...      ...
# 88878                                                NaN      Yes
# 88879                                                NaN       No
# 88880                                                NaN       No
# 88881                                                NaN       No
# 88882                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %% [markdown]
#  ### - Return Feature with most number of Nan values

# %%
pf.isnull().sum().sum()
# Out:
# 1028850
