# %%
import pandas as pd

# %%
df=pd.read_csv('pandas_docs/survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# ### - SAARC members does exist in this data

# %%
saarc=['India', 'Pakistan', 'Sri Lanka', 'Nepal', 'Maldives', 'Afghanistan', 'Bangladesh', 'Bhutan']
df[df['Country'].isin(saarc)]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 33             34  I am a student who is learning to code      Yes
# 41             42          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88834       81624                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
# 88875       88182                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %% [markdown]
# ### - Does OPEC countries exist find their respective converted compensation and their country

# %%
opec=['Qatar','Indonesia','Libya','The United Arab Emirates','Algeria','Nigeria','Ecuador','Gabon','Angola','Equatorial Guinea','Congo']

# %%
filter=df['Country'].isin(opec)

# %%
df.loc[filter,['ConvertedComp','Country']]
# Out:
#        ConvertedComp    Country
# 203           2664.0    Nigeria
# 340          36000.0    Ecuador
# 346              NaN    Nigeria
# 363              NaN    Nigeria
# 685           1668.0    Nigeria
# 882           2770.0    Nigeria
# 909           1332.0    Nigeria
# 946          18000.0    Ecuador
# 1011         53184.0    Nigeria
# 1098             NaN    Algeria
# 1147         27956.0  Indonesia
# 1164             NaN  Indonesia
# 1243             NaN  Indonesia
# 1346             NaN    Nigeria
# 1347         32256.0  Indonesia
# 1353             NaN  Indonesia
# 1370       1000000.0  Indonesia
# 1382             NaN  Indonesia
# 1417             NaN  Indonesia
# 1432           432.0  Indonesia
# 1536          9144.0    Algeria
# 1638             NaN    Nigeria
# 1646          1332.0    Nigeria
# 1733             NaN    Nigeria
# 1758         16487.0  Indonesia
# 1769          8316.0    Nigeria
# 1945             NaN    Ecuador
# 1996             NaN    Nigeria
# ...

# %% [markdown]
# ### - if education levels is masters then find their undergrad major

# %%
filte=df['LanguageWorkedWith'].str.contains('Master',na=False)

# %%
df.loc[filte,'LanguageWorkedWith']#incomlpete
# Out:
# Series([], Name: LanguageWorkedWith, dtype: object)

# %% [markdown]
# ### - if working location is home find their sexuality

# %%
filter1=df['WorkLoc'].isin(['Home'])

# %%
df.loc[filter1,['WorkLoc','Sexuality']]
# Out:
#       WorkLoc                Sexuality
# 2        Home  Straight / Heterosexual
# 3        Home  Straight / Heterosexual
# 5        Home  Straight / Heterosexual
# 9        Home                      NaN
# 12       Home  Straight / Heterosexual
# 15       Home  Straight / Heterosexual
# 21       Home  Straight / Heterosexual
# 24       Home  Straight / Heterosexual
# 25       Home           Gay or Lesbian
# 27       Home                      NaN
# 31       Home  Straight / Heterosexual
# 34       Home  Straight / Heterosexual
# 40       Home                      NaN
# 42       Home  Straight / Heterosexual
# 43       Home  Straight / Heterosexual
# 53       Home  Straight / Heterosexual
# 55       Home  Straight / Heterosexual
# 57       Home  Straight / Heterosexual
# 60       Home  Straight / Heterosexual
# 61       Home  Straight / Heterosexual
# 63       Home  Straight / Heterosexual
# 65       Home                      NaN
# 68       Home  Straight / Heterosexual
# ...

# %% [markdown]
# ### - if developer is satisfied in his career find their salary and Age

# %%
filter2=df['CareerSat'].isin(['Very satisfied','Slightly satisfied'])

# %%
df.loc[filter2,['CareerSat','ConvertedComp','Age']]
# Out:
#                 CareerSat  ConvertedComp   Age
# 2      Slightly satisfied         8820.0  28.0
# 3          Very satisfied        61000.0  22.0
# 5          Very satisfied       366420.0  28.0
# 6      Slightly satisfied            NaN  42.0
# 8      Slightly satisfied        95179.0  23.0
# 12         Very satisfied        90000.0  28.0
# 13         Very satisfied        57060.0  31.0
# 15         Very satisfied       455352.0  26.0
# 16     Slightly satisfied        65277.0  29.0
# 17     Slightly satisfied        21996.0   NaN
# 19         Very satisfied        41244.0  38.0
# 21     Slightly satisfied       103000.0  47.0
# 22     Slightly satisfied        69000.0  22.0
# 23         Very satisfied        26388.0  23.0
# 24         Very satisfied         6300.0  22.0
# 25         Very satisfied       114000.0  34.0
# 27         Very satisfied            NaN   NaN
# 28         Very satisfied       100000.0  32.0
# 31     Slightly satisfied      1100000.0  21.0
# ...

# %% [markdown]
# ### - if devloper is not satisfies find their working hours in a week

# %%
filter3=df['CareerSat'].isin(['Very dissatisfied', 'Slightly dissatisfied'])

# %%
df.loc[filter3,['CareerSat','WorkWeekHrs']]
# Out:
#                    CareerSat  WorkWeekHrs
# 4          Very dissatisfied         55.0
# 9      Slightly dissatisfied         70.0
# 18         Very dissatisfied          8.0
# 29     Slightly dissatisfied         36.0
# 42         Very dissatisfied         40.0
# 55     Slightly dissatisfied         40.0
# 63     Slightly dissatisfied         40.0
# 69     Slightly dissatisfied         40.0
# 74     Slightly dissatisfied         50.0
# 85     Slightly dissatisfied         50.0
# 89     Slightly dissatisfied         50.0
# 90         Very dissatisfied          NaN
# 96     Slightly dissatisfied         45.0
# 107    Slightly dissatisfied         40.0
# 118    Slightly dissatisfied         35.0
# 124    Slightly dissatisfied         40.0
# 130    Slightly dissatisfied         55.0
# 145    Slightly dissatisfied         45.0
# 152    Slightly dissatisfied         30.0
# 154    Slightly dissatisfied         40.0
# 158        Very dissatisfied         40.0
# ...

# %% [markdown]
# ### - if developer's age 1st code is less than 10 find their educational qualification

# %%
filter4=df['Age1stCode'].isin(['3','4','5','6','7','8','9','10'])
df.loc[filter4,['Age1stCode','EdLevel']]
# Out:
#       Age1stCode                                            EdLevel
# 0             10                          Primary/elementary school
# 25             8  Some college/university study without earning ...
# 35            10  Secondary school (e.g. American high school, G...
# 38             6           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 46            10          Other doctoral degree (Ph.D, Ed.D., etc.)
# 50             9  Some college/university study without earning ...
# 51             8  Some college/university study without earning ...
# 52            10  Secondary school (e.g. American high school, G...
# 60            10  Some college/university study without earning ...
# 62             7           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65             7        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 67             9           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 72             5        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...

# %% [markdown]
# ### - find 'R' developers who earns more than 500000

# %%
filter5=df['LanguageWorkedWith'].str.contains('R',na=False)

# %%
df[df['ConvertedComp']>50000].loc[filter5,['ConvertedComp','LanguageWorkedWith']]
# Out:
#        ConvertedComp                                 LanguageWorkedWith
# 5           366420.0                                         Java;R;SQL
# 8            95179.0  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 21          103000.0  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 22           69000.0  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 25          114000.0  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 46          187000.0                                      Java;PHP;Ruby
# 59          107000.0  Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# 61           87994.0  Bash/Shell/PowerShell;C++;Go;HTML/CSS;Java;Jav...
# 65          137490.0          Clojure;Go;HTML/CSS;Java;JavaScript;R;SQL
# 73          114575.0        HTML/CSS;Java;JavaScript;Kotlin;Python;Ruby
# 81          143932.0  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 94          110000.0                C#;HTML/CSS;JavaScript;Python;R;SQL
# ...

# %% [markdown]
# ### - If a developer is working with Django framework find their salary and Country

# %%
filter6=df['WebFrameWorkedWith'].str.contains('Django',na=False)

# %%
df.loc[filter6,['ConvertedComp','Country']]
# Out:
#        ConvertedComp                 Country
# 0                NaN          United Kingdom
# 1                NaN  Bosnia and Herzegovina
# 4                NaN                 Ukraine
# 9            13293.0                   India
# 20               NaN                  Canada
# 42           20623.0                   Spain
# 45               NaN           United States
# 48           60000.0                  Serbia
# 49            5597.0                   India
# 53           68268.0                  Sweden
# 61           87994.0             Netherlands
# 65          137490.0                 Germany
# 84           52704.0                 Germany
# 85           16008.0                   China
# 86           36060.0                  Brazil
# 98               NaN                   India
# 102              NaN      Russian Federation
# 105         160000.0           United States
# 106              NaN             Netherlands
# 120              NaN                   India
# ...

# %% [markdown]
# ### - if a developer is good at mysql find their job satisfaction level

# %%
filter7=df['LanguageWorkedWith'].str.contains('SQL',na=False)

# %%
df.loc[filter7,['LanguageWorkedWith','CareerSat']]
# Out:
#                                       LanguageWorkedWith  \
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5                                             Java;R;SQL
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 9                          C#;Go;JavaScript;Python;R;SQL
# 11      Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 14     Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 18            C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 19     Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 20     Assembly;Bash/Shell/PowerShell;C;C++;Go;Java;J...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 22     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 24                HTML/CSS;JavaScript;PHP;SQL;TypeScript
# ...

# %% [markdown]
# ### - Find Indian developers maximum salary when they are working from home

# %%
filter7=df['Country'].isin(['India'])

# %%
df[df['WorkLoc']=='Home'].loc[filter7,['ConvertedComp','Country','WorkLoc']]
# Out:
#        ConvertedComp Country WorkLoc
# 9            13293.0   India    Home
# 74           17491.0   India    Home
# 89           16788.0   India    Home
# 103           2169.0   India    Home
# 138           7556.0   India    Home
# 172           2016.0   India    Home
# 174              NaN   India    Home
# 176           2500.0   India    Home
# 218              NaN   India    Home
# 236          27986.0   India    Home
# 240              NaN   India    Home
# 261          11194.0   India    Home
# 269              NaN   India    Home
# 424              NaN   India    Home
# 824              NaN   India    Home
# 828          15392.0   India    Home
# 1007             NaN   India    Home
# 1075         13993.0   India    Home
# 1229             NaN   India    Home
# 1261             NaN   India    Home
# 1352          7836.0   India    Home
# 1460             NaN   India    Home
# 1598         19590.0   India    Home
# 1632             NaN   India    Home
# ...

# %% [markdown]
# ### - Find Indian developers maximum salary when they are working from office

# %%
df[df['WorkLoc']=='Office'].loc[filter7,['ConvertedComp','Country','WorkLoc']]
# Out:
#        ConvertedComp Country WorkLoc
# 64               NaN   India  Office
# 67           11194.0   India  Office
# 77            7696.0   India  Office
# 82          117540.0   India  Office
# 123           9095.0   India  Office
# 167            979.0   India  Office
# 289              NaN   India  Office
# 341              NaN   India  Office
# 342              NaN   India  Office
# 372          94451.0   India  Office
# 386          16788.0   India  Office
# 391              NaN   India  Office
# 402          10495.0   India  Office
# 404          10800.0   India  Office
# 461           9655.0   India  Office
# 468           2520.0   India  Office
# 469           4200.0   India  Office
# 471           4536.0   India  Office
# 472           4897.0   India  Office
# 486              NaN   India  Office
# 488              NaN   India  Office
# 518          11894.0   India  Office
# 558              NaN   India  Office
# 579              NaN   India  Office
# ...

# %% [markdown]
# ### - Find Indian Graduates Salary and Age

# %%
#incomplete

# %% [markdown]
# ### - Find American women developers salary and job satisfaction

# %%
filter8=df['Country'].isin(['United States'])

# %%
df[df['Gender']=='Woman'].loc[filter8,['ConvertedComp','CareerSat','Country']]
# Out:
#        ConvertedComp              CareerSat        Country
# 34           80000.0     Slightly satisfied  United States
# 50               NaN                    NaN  United States
# 104          45000.0         Very satisfied  United States
# 140         180000.0         Very satisfied  United States
# 146         135000.0         Very satisfied  United States
# 184              NaN                    NaN  United States
# 185              NaN         Very satisfied  United States
# 225              NaN         Very satisfied  United States
# 234              NaN     Slightly satisfied  United States
# 306         140000.0         Very satisfied  United States
# 314          84000.0         Very satisfied  United States
# 319         140000.0         Very satisfied  United States
# 378              NaN     Slightly satisfied  United States
# 384              NaN         Very satisfied  United States
# 431              NaN                    NaN  United States
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Gender']
# Out:
# 0                                                      Man
# 1                                                      Man
# 2                                                      Man
# 3                                                      Man
# 4                                                      Man
# 5                                                      Man
# 6                                                      Man
# 7                                                      Man
# 8                                                      Man
# 9                                                      NaN
# 10                                                     Man
# 11                                                   Woman
# 12                                                     Man
# 13                                                     Man
# 14                                                     Man
# 15                                                     Man
# ...
